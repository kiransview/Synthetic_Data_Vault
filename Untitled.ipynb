# %%
import pandas as pd
from sdv.metadata import SingleTableMetadata

# %%
df = pd.read_csv("SampleDataFoodSales.csv")
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(data=df)

# %%
#         'Cookies': 'Chocolate Chip',
#         'Cookies': 'Arrowroot',
#         'Cookies': 'Oatmeal Raisin',
#         'Bars': 'Carrot',
#         'Bars': 'Bran',
#         'Bars': 'Banana',
#         'Snacks': 'Potato Chips',
#         'Snacks': 'Pretzels',
#         'Crackers': 'Whole Wheat'

# %%
constraint = {
    'constraint_class': 'FixedCombinations',
    'constraint_parameters': {
        'column_names': ['Category', 'Product']
    }
}

# %%
from sdv.single_table import GaussianCopulaSynthesizer

synthesizer = GaussianCopulaSynthesizer(metadata)
synthesizer.add_constraints(constraints=[
    constraint
])
synthesizer.fit(df)
synthetic_data = synthesizer.sample(num_rows=1000)
# Out:
# Sampling rows: 100%|████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 14281.54it/s]

# %%
synthetic_data.to_csv("test.csv")

# %%
checkin_checkout_constraint = {
    'constraint_class': 'Cat_pro_mapping',
    'constraint_parameters': {
  
    }
}

# %%
checkin_checkout_constraint = {
    'constraint_class': 'Cat_pro_mapping',
    'constraint_parameters': {
        'Cookies': 'Chocolate Chip',
        'Cookies': 'Arrowroot',
        'Cookies': 'Oatmeal Raisin',
        'Bars': 'Carrot',
        'Bars': 'Bran',
        'Bars': 'Banana',
        'Snacks': 'Potato Chips',
        'Snacks': 'Pretzels',
        'Crackers': 'Whole Wheat'        
    }
}
# Out:
#           ID    Date Region         City  Category         Product  Qty  \
# 0    ID07568  28-Oct   East     New York  Crackers  Chocolate Chip   27
# 1    ID07356  25-Jan   East  Los Angeles  Crackers  Chocolate Chip   67
# 2    ID07447  21-Feb   West       Boston  Crackers            Bran   33
# 3    ID07509  20-Jan   West  Los Angeles      Bars  Chocolate Chip   76
# 4    ID07535  12-Nov   East       Boston    Snacks     Whole Wheat   80
# ..       ...     ...    ...          ...       ...             ...  ...
# 495  ID07509  23-Aug   West     New York    Snacks        Pretzels   91
# 496  ID07465   3-Dec   West     New York      Bars  Chocolate Chip   36
# 497  ID07354  21-Feb   West       Boston    Snacks    Potato Chips   23
# 498  ID07406  13-Oct   West    San Diego   Cookies  Oatmeal Raisin   26
# 499  ID07456   9-Jul   West  Los Angeles   Cookies     Whole Wheat  115
#
#      UnitPrice  TotalPrice
# 0         1.68       57.23
# 1         1.68       90.72
# 2         2.41      121.41
# 3         2.74      226.55
# 4         2.50      274.07
# ..         ...         ...
# 495       2.07      185.25
# 496       1.76       67.04
# 497       1.70       61.85
# 498       1.68       50.50
# 499       1.68      213.30
#
# [500 rows x 9 columns]

# %%
from sdv import SDV
sdv = SDV()
sdv.fit(data)

# Generate synthetic data
synthetic_data = sdv.sample()

# Print the synthetic data
print(synthetic_data)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 from sdv import SDV
#       2 sdv = SDV()
#       3 sdv.fit(data)
#
# ImportError: cannot import name 'SDV' from 'sdv' (C:\Users\shashi.kiran\Anaconda3\lib\site-packages\sdv\__init__.py)
